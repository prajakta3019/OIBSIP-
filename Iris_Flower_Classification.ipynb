# %% [raw]
# # TASKNO:01
# author: prajakta chavan
# batch :15THfeb-15H MARCH 2024
# domain: data science
# project name: IRIS FLOWER CLASSIFICATION USING MACHINE LEARNING

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
sns.set(style="white",color_codes=True)

# %%
#irisflowerclassification path 
df=pd.read_csv(r'C:\Users\Dell\Desktop\irisflowerclassification.csv')

# %%
#print irisflowerclassification 
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#print 1st data for irisflowerclassification
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#pandas and dataframe and overview project
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#Species value integerformats and print data 
df['Species'],categories=pd.factorize(df['Species'])
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]>

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df["Species"].value_counts()
# Out:
# Species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
#describe data
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
#
#           Species
# count  150.000000
# mean     1.000000
# std      0.819232
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
y=df.iloc[:,4]
y
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: PetalWidthCm, Length: 150, dtype: float64

# %%
x=df.iloc[:,0:4]
x
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0      1            5.1           3.5            1.4
# 1      2            4.9           3.0            1.4
# 2      3            4.7           3.2            1.3
# 3      4            4.6           3.1            1.5
# 4      5            5.0           3.6            1.4
# ..   ...            ...           ...            ...
# 145  146            6.7           3.0            5.2
# 146  147            6.3           2.5            5.0
# 147  148            6.5           3.0            5.2
# 148  149            6.2           3.4            5.4
# 149  150            5.9           3.0            5.1
#
# [150 rows x 4 columns]

# %%
print(x.shape)
print (y.shape)
# Out:
# (150, 4)
# (150,)

# %%
plt.boxplot(df['SepalLengthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a18f247250>,
#   <matplotlib.lines.Line2D at 0x1a18f2d3290>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a18b7d4a50>,
#   <matplotlib.lines.Line2D at 0x1a18f3106d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a18f28f090>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a18f310f50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a18f311790>],
#  'means': []}

# %%
plt.boxplot(df['SepalWidthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a18ffa8950>,
#   <matplotlib.lines.Line2D at 0x1a18fd75190>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a18fd77c10>,
#   <matplotlib.lines.Line2D at 0x1a18fd76890>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a18fec4650>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a18fd740d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a18fd42390>],
#  'means': []}

# %%
plt.boxplot(df['PetalLengthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a18f253950>,
#   <matplotlib.lines.Line2D at 0x1a18f2533d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a18f2522d0>,
#   <matplotlib.lines.Line2D at 0x1a18f251710>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a18f2261d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a18f2524d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a18fcebe10>],
#  'means': []}

# %%
plt.boxplot(df['PetalWidthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a19006e8d0>,
#   <matplotlib.lines.Line2D at 0x1a19006f490>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a18ff2fa10>,
#   <matplotlib.lines.Line2D at 0x1a190074a90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a19006ddd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a190075590>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a190075f10>],
#  'means': []}

# %%
df['SepalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df['SepalWidthCm'].hist()
# Out:
# <Axes: >

# %%
df['PetalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df['PetalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df['PetalWidthCm'].hist()
# Out:
# <Axes: >

# %%
#graph point :
sns.pairplot(df,hue='Species')

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=df)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=df)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=df)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
#import the data 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
from sklearn.model_selection import train_test_split
#train-70
#test=30
x=df.drop(columns=['Species'])
y=df['Species']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.50)

# %%
#LogisticRegression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_test,y_test)
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 100.0

# %%
#kneighborsclassifier
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 97.33333333333334

# %%
#decisin making 
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 98.66666666666667

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(x_train,y_train)

pred_y = model.predict(x_test)

from sklearn.metrics import accuracy_score
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 96.0

# %%
results = pd.DataFrame({
    'Model': ['Logistic Regression','KNeighborsClassifier','DecisionTreeClassifier','SVC'],
    'Score': [100.0,97.33333333333334,98.66666666666667,96.0]})

result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df.head(9)
# Out:
#                              Model
# Score
# 100.000000     Logistic Regression
# 98.666667   DecisionTreeClassifier
# 97.333333     KNeighborsClassifier
# 96.000000                      SVC
